# %% [markdown]
# # import pandas as pd

# %%
df_2010=pd.read_excel("D:\online+retail+ii-1\Online Retail Data.xlsx", sheet_name="Year 2010-2011")

# %%
df_2010['InvoiceDate'] = pd.to_datetime(df_2010['InvoiceDate'])

# %%
df_2010_2011 = df_2010[df_2010['InvoiceDate'].dt.year == 2010]

# %%
# Random sample of 10,000 rows
df = df_2010_2011.sample(n=10000, random_state=42)

# %%
#Exploring the dataset
df.head()
# Out:
#       Invoice StockCode                          Description  Quantity  \
# 39870  539708     35924        HANGING FAIRY CAKE DECORATION         1
# 33310  539246    85114C        RED ENCHANTED FOREST PLACEMAT         8
# 624    536415     22910    PAPER CHAIN KIT VINTAGE CHRISTMAS         5
# 11578  537254     20975  12 PENCILS SMALL TUBE RED RETROSPOT         4
# 30427  538864     21485     RETROSPOT HEART HOT WATER BOTTLE        24
#
#               InvoiceDate  Price  Customer ID         Country
# 39870 2010-12-21 12:18:00   4.21          NaN  United Kingdom
# 33310 2010-12-16 13:33:00   1.65      14606.0  United Kingdom
# 624   2010-12-01 11:57:00   2.95      12838.0  United Kingdom
# 11578 2010-12-06 11:01:00   0.65      15898.0  United Kingdom
# 30427 2010-12-14 14:26:00   4.25      17739.0  United Kingdom

# %%
df.tail()
# Out:
#       Invoice StockCode                        Description  Quantity  \
# 41210  539760     15036          ASSORTED COLOURS SILK FAN        12
# 19055  537827     22145    CHRISTMAS CRAFT HEART STOCKING         30
# 5513   536864     21488  RED WHITE SCARF  HOT WATER BOTTLE         1
# 22171  538153     82599        FANNY'S REST STOPMETAL SIGN         1
# 42301  539981    85099B            JUMBO BAG RED RETROSPOT        10
#
#               InvoiceDate  Price  Customer ID         Country
# 41210 2010-12-21 17:16:00   0.75      17400.0  United Kingdom
# 19055 2010-12-08 14:43:00   2.10      15332.0       Lithuania
# 5513  2010-12-03 11:27:00   8.47          NaN  United Kingdom
# 22171 2010-12-09 16:31:00   4.21          NaN  United Kingdom
# 42301 2010-12-23 14:35:00   1.95      13304.0  United Kingdom

# %%
df.describe()
# Out:
#            Quantity                    InvoiceDate         Price   Customer ID
# count  10000.000000                          10000  10000.000000   6334.000000
# mean       7.193600  2010-12-10 16:25:01.973999872      6.605233  15490.827281
# min    -9360.000000            2010-12-01 08:26:00      0.000000  12347.000000
# 25%        1.000000            2010-12-06 09:58:00      1.280000  14135.000000
# 50%        2.000000            2010-12-09 14:09:00      2.510000  15544.000000
# 75%        7.000000            2010-12-15 14:25:00      4.650000  17069.000000
# max     1824.000000            2010-12-23 16:49:00  13541.330000  18269.000000
# std       99.712289                            NaN    148.030499   1739.345921

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 39870 to 42301
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Invoice      10000 non-null  object
#  1   StockCode    10000 non-null  object
#  2   Description  9975 non-null   object
#  3   Quantity     10000 non-null  int64
#  4   InvoiceDate  10000 non-null  datetime64[ns]
#  5   Price        10000 non-null  float64
#  6   Customer ID  6334 non-null   float64
#  7   Country      10000 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 703.1+ KB

# %%
df.shape
# Out:
# (10000, 8)

# %%
df[df['Customer ID'].isnull()]
# Out:
#       Invoice StockCode                         Description  Quantity  \
# 39870  539708     35924       HANGING FAIRY CAKE DECORATION         1
# 11359  537240     85177        BASKET OF FLOWERS SEWING KIT         2
# 21278  538071     85096             HILDA CANDY SPOT RABBIT         1
# 40813  539743     22135          MINI LADLE LOVE HEART PINK         1
# 10709  537237     82582           AREA PATROLLED METAL SIGN         1
# ...       ...       ...                                 ...       ...
# 5859   536876     22419                    LIPSTICK PEN RED         7
# 10331  537237     21641  ASSORTED TUTTI FRUTTI KEYRING BALL         1
# 22610  538177     20682    RED RETROSPOT CHILDRENS UMBRELLA         2
# 5513   536864     21488   RED WHITE SCARF  HOT WATER BOTTLE         1
# 22171  538153     82599         FANNY'S REST STOPMETAL SIGN         1
#
#               InvoiceDate  Price  Customer ID         Country
# 39870 2010-12-21 12:18:00   4.21          NaN  United Kingdom
# ...

# %%
df[df['Description'].isnull()]
# Out:
#       Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 14217  537466     21488         NaN       -50 2010-12-07 10:33:00    0.0
# 19625  537872     21595         NaN         1 2010-12-08 18:07:00    0.0
# 7191   536999     21421         NaN       110 2010-12-03 15:32:00    0.0
# 1985   536547     37509         NaN         1 2010-12-01 14:33:00    0.0
# 14064  537453     21248         NaN       -18 2010-12-07 09:28:00    0.0
# 7205   537013     35965         NaN       -25 2010-12-03 15:40:00    0.0
# 4347   536764    84952C         NaN       -38 2010-12-02 14:42:00    0.0
# 22581  538173     22353         NaN       -28 2010-12-10 09:35:00    0.0
# 7193   537001     21653         NaN        -6 2010-12-03 15:33:00    0.0
# 20330  538038     21488         NaN         8 2010-12-09 13:07:00    0.0
# 14065  537454     21349         NaN       -44 2010-12-07 09:30:00    0.0
# 19628  537877     21661         NaN         1 2010-12-08 18:08:00    0.0
# ...

# %%
df[df['Invoice']==0].shape[0]
# Out:
# 0

# %%
df[df['StockCode']==0].shape[0]
# Out:
# 0

# %%
df[df['Description'].isna()].shape[0]
# Out:
# 25

# %%
df[df['Quantity']<0].shape[0]
# Out:
# 167

# %%
df[df['Quantity']==0].shape[0]
# Out:
# 0

# %%
df[df['InvoiceDate'].isnull()].shape[0]
# Out:
# 0

# %%
df[df['Price']==0].shape[0]
# Out:
# 53

# %%
df[df['Price']<0].shape[0]
# Out:
# 0

# %%
df[df['Customer ID'].isna()].shape[0]
# Out:
# 3666

# %%
df[df['Country'].isnull()].shape[0]
# Out:
# 0

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'Germany', 'Switzerland', 'EIRE', 'Finland',
#        'France', 'Spain', 'Belgium', 'Japan', 'Poland', 'Cyprus',
#        'Norway', 'Iceland', 'Portugal', 'Australia', 'Lithuania',
#        'Netherlands', 'Italy', 'Austria', 'Sweden', 'Denmark',
#        'Channel Islands'], dtype=object)

# %%
#Droping Duplicates
df.duplicated().sum()
# Out:
# np.int64(25)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (9975, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9975 entries, 39870 to 42301
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Invoice      9975 non-null   object
#  1   StockCode    9975 non-null   object
#  2   Description  9950 non-null   object
#  3   Quantity     9975 non-null   int64
#  4   InvoiceDate  9975 non-null   datetime64[ns]
#  5   Price        9975 non-null   float64
#  6   Customer ID  6309 non-null   float64
#  7   Country      9975 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 701.4+ KB

# %%
#Standardizing Data
#Invoice Cleaning
df['Invoice'].unique()
# Out:
# array([539708, 539246, 536415, ..., 539865, 538871, 537827],
#       shape=(1437,), dtype=object)

# %%
invoice_letter = df['Invoice'].astype(str).str.contains('[a-zA-Z]',regex=True)

# %%
print(df[invoice_letter]['Invoice'].unique())
# Out:
# ['C537602' 'C539644' 'C538834' 'C538341' 'C537251' 'C537860' 'C538882'
#  'C538833' 'C537157' 'C538874' 'C538084' 'C537853' 'C537647' 'C538898'
#  'C536812' 'C537684' 'C537857' 'C538103' 'C536817' 'C539069' 'C539573'
#  'C539950' 'C538059' 'C537788' 'C537402' 'C537164' 'C539067' 'C537132'
#  'C538376' 'C538681' 'C536548' 'C539632' 'C539657' 'C539602' 'C536822'
#  'C538115' 'C538682' 'C538350' 'C539276' 'C538377' 'C538314' 'C539603'
#  'C538643' 'C538705' 'C536543' 'C539605' 'C538119' 'C538102' 'C539104'
#  'C537856' 'C539066' 'C537807' 'C539273' 'C537797' 'C536854' 'C539270'
#  'C539945' 'C539943' 'C539058' 'C538052' 'C539709' 'C537805' 'C539947'
#  'C539097' 'C539031' 'C538100' 'C539661' 'C539576' 'C539606' 'C538105'
#  'C539221' 'C537893' 'C538650' 'C539114' 'C539486' 'C539956' 'C536850'
#  'C536391' 'C536642' 'C537600' 'C538726' 'C539832' 'C538362' 'C536814'
#  'C536828' 'C538536' 'C537812' 'C539071' 'C538713' 'C538693' 'C537835'
# ...

# %%
print(df[invoice_letter]['Invoice'].shape[0])
# Out:
# 153

# %%
cancel_orders=df[invoice_letter & (df['Quantity']>0)]
print(cancel_orders)
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country]
# Index: []

# %%
import numpy as np

# %%
df['Order_Status']=np.where(invoice_letter,'Cancelled','Completed')

# %%
df[invoice_letter]
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 14528  C537602     22654                   DELUXE SEWING KIT         -1
# 39450  C539644     21578     WOODLAND DESIGN  COTTON TOTE BAG        -2
# 29948  C538834     22618                COOKING SET RETROSPOT        -1
# 24176  C538341     22727            ALARM CLOCK BAKELIKE RED         -2
# 11511  C537251     84347  ROTATING SILVER ANGELS T-LIGHT HLDR        -9
# ...        ...       ...                                  ...       ...
# 24915  C538350    85099F                 JUMBO BAG STRAWBERRY        -2
# 38949  C539605     21314        SMALL GLASS HEART TRINKET POT        -3
# 17354  C537746     71477    COLOUR GLASS. STAR T-LIGHT HOLDER        -1
# 4877   C536814    72799E     IVORY PILLAR CANDLE SILVER FLOCK        -6
# 29279  C538723     21217        RED RETROSPOT ROUND CAKE TINS        -1
#
#               InvoiceDate  Price  Customer ID         Country Order_Status
# ...

# %%
df['Invoice']=df['Invoice'].astype(str).str.extract(r'(\d+)')

# %%
verify_invoice = df['Invoice'].astype(str).str.contains('[a-zA-Z]',regex=True)

# %%
print(df[verify_invoice]['Invoice'].unique())
# Out:
# []

# %%
#StockCode Cleaning
stock_letter = df['StockCode'].astype(str).str.contains('[a-zA-Z]',regex=True)

# %%
print(df[stock_letter]['StockCode'].unique())
# Out:
# ['85114C' '85135C' '90130B' '85132A' '35004B' '84559a' '85035A' '84030E'
#  '47343A' '85049A' '84913A' '85049G' '84596G' '17012C' '82494L' 'M'
#  '85049E' '84997A' '84520B' '90211B' '85123A' '84313C' '82613D' '17012D'
#  '84968F' '48173c' '84884a' '84997C' '84029E' '15056N' '85014A' '72800E'
#  '90200C' '47559B' '72351A' '85131D' '84870C' '47591D' '90024C' '85032D'
#  '85099B' '35471D' '72807C' '18098C' '85231G' '84029G' '84031B' '47593B'
#  '90013C' '84536B' '35095A' '85132B' '72800B' '85099C' '85040A' '35916C'
#  'POST' '85231B' '85049H' '84970l' '84970S' '85131B' 'C2' '90183A'
#  '72349B' '84406B' '85099F' '84849D' '84558A' 'AMAZONFEE' '47367B'
#  '85017A' '46000P' '85184C' '84251B' '85169A' '72801d' '85035B' '85031A'
#  '46000S' '84247G' '84031A' '85014B' '85169D' '84970L' '90081A' '18097C'
#  '85035b' '35833G' '90198A' '82001S' '84032B' '17013D' '79051A' '84997D'
#  '72760B' '85131C' '85123a' '85019C' '17091J' 'D' '15056P' '90214P'
# ...

# %%
stock_format=df['StockCode'].astype(str).str.contains(r'^\d+[a-zA-Z]*$',regex=True)

# %%
unique_stock=df[~stock_format]['StockCode'].unique()

# %%
print(unique_stock)
# Out:
# ['M' 'POST' 'C2' 'AMAZONFEE' 'D' 'DOT' 'gift_0001_50' 'gift_0001_40']

# %%
type_mapping={'M':'Manual Adjustment',
              'POST':'Postage Fee',
              'C2':'Special Carriage Fee',
              'AMAZONFEE':'Platform Fee',
              'D':'Dicsount',
              'DOT':'Dotcom Overhead',
              'gift_0001_50':'Gift Voucher',
              'gift_0001_40':'Gift Voucher'
             }

# %%
df['StockCode']=df['StockCode'].replace(type_mapping)

# %%
print(df['StockCode'].value_counts())
# Out:
# StockCode
# 85123A    52
# 22834     48
# 22111     39
# 22837     38
# 22086     37
#           ..
# 84596E     1
# 21379      1
# 85194L     1
# 72132      1
# 22145      1
# Name: count, Length: 2056, dtype: int64

# %%
df['StockCode'].unique()
# Out:
# array([35924, '85114C', 22910, ..., '47504H', '90214N', 22145],
#       shape=(2056,), dtype=object)

# %%
clean_stock=df['StockCode'].astype(str).str.contains(r'^\d+[a-zA-Z]*$',regex=True)

# %%
clean_two_stock=df[~clean_stock]['StockCode'].unique()

# %%
print(clean_two_stock)
# Out:
# ['Manual Adjustmnt' 'Postage Fee' 'Special Carriage Fee' 'Platform Fee'
#  'Dicsount' 'Dotcom Overhead' 'Gift Voucher']

# %%
lowercase_mask=df[df['StockCode'].astype(str).str.contains(r'[a-z]')].copy()
print(lowercase_mask)
# Out:
#       Invoice         StockCode                       Description  Quantity  \
# 40581  539738            84559a          3D SHEET OF DOG STICKERS         1
# 18186  537804  Manual Adjustmnt                            Manual        12
# 30703  538877            48173c              DOORMAT BLACK FLOCK          1
# 5676   536865            84884a       ANT WHITE WIRE HEART SPIRAL         1
# 40884  539744            84559a          3D SHEET OF DOG STICKERS         1
# ...       ...               ...                               ...       ...
# 38609  539589          Dicsount                          Discount        -1
# 5685   536865  Manual Adjustmnt                            Manual         1
# 34471  539391       Postage Fee                           POSTAGE         2
# 41045  539750            85099f              JUMBO BAG STRAWBERRY         2
# 15978  537642            84970l  SINGLE HEART ZINC T-LIGHT HOLDER         1
#
# ...

# %%
lowercase_mask['StockCode']=lowercase_mask['StockCode'].astype(str).str.upper()

# %%
df.update(lowercase_mask)

# %%
verify_lowercase=df[df['StockCode'].astype(str).str.contains(r'[a-z]')]
print(verify_lowercase)
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country, Order_Status]
# Index: []

# %%
df['StockCode']=df['StockCode'].replace('MANUAL ADJUSTMNT','Manual Adjustment')

# %%
df['StockCode']=df['StockCode'].replace('POSTAGE FEE','Postage Fee')
df['StockCode']=df['StockCode'].replace('SPECIAL CARRIAGE FEE','Special Carriage Fee')
df['StockCode']=df['StockCode'].replace('PLATFORM FEE','Platform Fee')
df['StockCode']=df['StockCode'].replace('DICSOUNT','Discount')
df['StockCode']=df['StockCode'].replace('DOTCOM OVERHEAD','Dotcom Overhead')
df['StockCode']=df['StockCode'].replace('GIFT VOUCHER','Gift Voucher')

# %%
df[df['StockCode']=='Gift Voucher']
# Out:
#       Invoice     StockCode                         Description  Quantity  \
# 42057  539958  Gift Voucher  Dotcomgiftshop Gift Voucher £50.00         1
# 38248  539492  Gift Voucher  Dotcomgiftshop Gift Voucher £40.00         1
#
#               InvoiceDate  Price  Customer ID         Country Order_Status
# 42057 2010-12-23 13:26:00  42.55          NaN  United Kingdom    Completed
# 38248 2010-12-20 10:14:00  34.04          NaN  United Kingdom    Completed

# %%
#Description Cleaning
special_char=df['Description'].astype(str).str.contains(r'[a-zA-Z\s]',na=False)

# %%
special_description=df[special_char]['Description'].unique()

# %%
print(special_description)
# Out:
# ['HANGING FAIRY CAKE DECORATION' 'RED ENCHANTED FOREST PLACEMAT'
#  'PAPER CHAIN KIT VINTAGE CHRISTMAS' ... 'ENGLISH ROSE SPIRIT LEVEL '
#  'LETTER "N" BLING KEY RING' 'CHRISTMAS CRAFT HEART STOCKING ']

# %%
junk=df['Description'].astype(str).str.contains(r'^[?_\-:]+$',na=False)

# %%
print(df[junk]['Description'].unique())
# Out:
# []

# %%
junk_index=df[df['Description']=='?'].index

# %%
df=df.drop(index=junk_index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9974 entries, 39870 to 42301
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Invoice       9974 non-null   object
#  1   StockCode     9974 non-null   object
#  2   Description   9949 non-null   object
#  3   Quantity      9974 non-null   int64
#  4   InvoiceDate   9974 non-null   datetime64[ns]
#  5   Price         9974 non-null   float64
#  6   Customer ID   6309 non-null   float64
#  7   Country       9974 non-null   object
#  8   Order_Status  9974 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 779.2+ KB

# %%
df[df['Description'].astype(str).str.isupper()]
# Out:
#       Invoice StockCode                          Description  Quantity  \
# 39870  539708     35924        HANGING FAIRY CAKE DECORATION         1
# 33310  539246    85114C        RED ENCHANTED FOREST PLACEMAT         8
# 624    536415     22910    PAPER CHAIN KIT VINTAGE CHRISTMAS         5
# 11578  537254     20975  12 PENCILS SMALL TUBE RED RETROSPOT         4
# 30427  538864     21485     RETROSPOT HEART HOT WATER BOTTLE        24
# ...       ...       ...                                  ...       ...
# 41210  539760     15036            ASSORTED COLOURS SILK FAN        12
# 19055  537827     22145      CHRISTMAS CRAFT HEART STOCKING         30
# 5513   536864     21488    RED WHITE SCARF  HOT WATER BOTTLE         1
# 22171  538153     82599          FANNY'S REST STOPMETAL SIGN         1
# 42301  539981    85099B              JUMBO BAG RED RETROSPOT        10
#
#               InvoiceDate  Price  Customer ID         Country Order_Status
# ...

# %%
df[df['Description'].astype(str).str.istitle()]
# Out:
#       Invoice StockCode                          Description  Quantity  \
# 39870  539708     35924        Hanging Fairy Cake Decoration         1
# 33310  539246    85114C        Red Enchanted Forest Placemat         8
# 624    536415     22910    Paper Chain Kit Vintage Christmas         5
# 11578  537254     20975  12 Pencils Small Tube Red Retrospot         4
# 30427  538864     21485     Retrospot Heart Hot Water Bottle        24
# ...       ...       ...                                  ...       ...
# 41210  539760     15036            Assorted Colours Silk Fan        12
# 19055  537827     22145      Christmas Craft Heart Stocking         30
# 5513   536864     21488    Red White Scarf  Hot Water Bottle         1
# 22171  538153     82599          Fanny'S Rest Stopmetal Sign         1
# 42301  539981    85099B              Jumbo Bag Red Retrospot        10
#
#               InvoiceDate  Price  Customer ID         Country Order_Status
# ...

# %%
df['Description']=df['Description'].replace('Dotcomgiftshop Gift Voucher £50.00','Gift Voucher £50.00')
df['Description']=df['Description'].replace('Dotcomgiftshop Gift Voucher £40.00','Gift Voucher £40.00')

# %%
upper=df['Description'].apply(lambda x:isinstance(x,str) and x.isupper())
preview_df=df[upper][['Description']].copy()
preview_df['Proposed_description']=preview_df['Description'].str.title()
preview_df
# Out:
#                                Description  \
# 39870        HANGING FAIRY CAKE DECORATION
# 33310        RED ENCHANTED FOREST PLACEMAT
# 624      PAPER CHAIN KIT VINTAGE CHRISTMAS
# 11578  12 PENCILS SMALL TUBE RED RETROSPOT
# 30427     RETROSPOT HEART HOT WATER BOTTLE
# ...                                    ...
# 41210            ASSORTED COLOURS SILK FAN
# 19055      CHRISTMAS CRAFT HEART STOCKING
# 5513     RED WHITE SCARF  HOT WATER BOTTLE
# 22171          FANNY'S REST STOPMETAL SIGN
# 42301              JUMBO BAG RED RETROSPOT
#
#                       Proposed_description
# 39870        Hanging Fairy Cake Decoration
# 33310        Red Enchanted Forest Placemat
# 624      Paper Chain Kit Vintage Christmas
# 11578  12 Pencils Small Tube Red Retrospot
# 30427     Retrospot Heart Hot Water Bottle
# ...                                    ...
# 41210            Assorted Colours Silk Fan
# 19055      Christmas Craft Heart Stocking
# 5513     Red White Scarf  Hot Water Bottle
# ...

# %%
is_upper=df['Description'].apply(lambda x:isinstance(x,str) and x.isupper())
df.loc[is_upper,'Description']=df.loc[is_upper,'Description'].str.title()

# %%
df[df['Description']=='Manual']
# Out:
#       Invoice          StockCode Description  Quantity         InvoiceDate  \
# 18186  537804  Manual Adjustment      Manual        12 2010-12-08 13:17:00
# 7976   537077  Manual Adjustment      Manual        12 2010-12-05 11:59:00
# 28993  538681  Manual Adjustment      Manual        -1 2010-12-13 17:12:00
# 28994  538682  Manual Adjustment      Manual        -1 2010-12-13 17:14:00
# 2239   536569  Manual Adjustment      Manual         1 2010-12-01 15:35:00
# 13954  537435  Manual Adjustment      Manual         2 2010-12-06 16:58:00
# 12783  537396  Manual Adjustment      Manual         1 2010-12-06 14:08:00
# 21758  538124  Manual Adjustment      Manual        -4 2010-12-09 15:43:00
# 28007  538597  Manual Adjustment      Manual         1 2010-12-13 12:26:00
# 5685   536865  Manual Adjustment      Manual         1 2010-12-03 11:28:00
#
#          Price  Customer ID         Country Order_Status
# 18186     0.19      12748.0  United Kingdom    Completed
# ...

# %%
#Invoice Date Extract Columns
print(df['InvoiceDate'].dtype)
# Out:
# datetime64[ns]

# %%
df['Invoice_Date_Only']=df['InvoiceDate'].dt.date

# %%
df['Week_Beginning']=df['InvoiceDate'].dt.to_period('W').dt.start_time

# %%
df
# Out:
#       Invoice StockCode                          Description  Quantity  \
# 39870  539708     35924        Hanging Fairy Cake Decoration         1
# 33310  539246    85114C        Red Enchanted Forest Placemat         8
# 624    536415     22910    Paper Chain Kit Vintage Christmas         5
# 11578  537254     20975  12 Pencils Small Tube Red Retrospot         4
# 30427  538864     21485     Retrospot Heart Hot Water Bottle        24
# ...       ...       ...                                  ...       ...
# 41210  539760     15036            Assorted Colours Silk Fan        12
# 19055  537827     22145      Christmas Craft Heart Stocking         30
# 5513   536864     21488    Red White Scarf  Hot Water Bottle         1
# 22171  538153     82599          Fanny'S Rest Stopmetal Sign         1
# 42301  539981    85099B              Jumbo Bag Red Retrospot        10
#
#               InvoiceDate  Price  Customer ID         Country Order_Status  \
# ...

# %%
#Customer ID clean
print(df['Customer ID'].dtype)
# Out:
# Int64

# %%
df['Customer ID']=df['Customer ID'].astype('Int64')

# %%
df
# Out:
#       Invoice StockCode                          Description  Quantity  \
# 39870  539708     35924        Hanging Fairy Cake Decoration         1
# 33310  539246    85114C        Red Enchanted Forest Placemat         8
# 624    536415     22910    Paper Chain Kit Vintage Christmas         5
# 11578  537254     20975  12 Pencils Small Tube Red Retrospot         4
# 30427  538864     21485     Retrospot Heart Hot Water Bottle        24
# ...       ...       ...                                  ...       ...
# 41210  539760     15036            Assorted Colours Silk Fan        12
# 19055  537827     22145      Christmas Craft Heart Stocking         30
# 5513   536864     21488    Red White Scarf  Hot Water Bottle         1
# 22171  538153     82599          Fanny'S Rest Stopmetal Sign         1
# 42301  539981    85099B              Jumbo Bag Red Retrospot        10
#
#               InvoiceDate  Price  Customer ID         Country Order_Status  \
# ...

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'Germany', 'Switzerland', 'Ireland', 'Finland',
#        'France', 'Spain', 'Belgium', 'Japan', 'Poland', 'Cyprus',
#        'Norway', 'Iceland', 'Portugal', 'Australia', 'Lithuania',
#        'Netherlands', 'Italy', 'Austria', 'Sweden', 'Denmark',
#        'Channel Islands'], dtype=object)

# %%
df['Country'] = df['Country'].str.replace('EIRE', 'Ireland')

# %%
df[df['Country']=='EIRE']
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country, Order_Status, Invoice_Date_Only, Week_Beginning]
# Index: []

# %%
df[(df['Quantity'] < 0) & (df['Order_Status']=='Completed') & (df['Price']==0) & (df['Customer ID']==0)]
# Out:
#       Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 14217  537466     21488     Unknown       -50 2010-12-07 10:33:00    0.0
# 14064  537453     21248     Unknown       -18 2010-12-07 09:28:00    0.0
# 7205   537013     35965     Unknown       -25 2010-12-03 15:40:00    0.0
# 4347   536764    84952C     Unknown       -38 2010-12-02 14:42:00    0.0
# 22581  538173     22353     Unknown       -28 2010-12-10 09:35:00    0.0
# 7193   537001     21653     Unknown        -6 2010-12-03 15:33:00    0.0
# 14065  537454     21349     Unknown       -44 2010-12-07 09:30:00    0.0
# 20394  538043     22833     Unknown        -1 2010-12-09 13:10:00    0.0
# 7212   537020     21807     Unknown       -30 2010-12-03 15:43:00    0.0
# 7201   537010     22162     Unknown       -40 2010-12-03 15:38:00    0.0
# 20494  538054    85167B     Unknown       -24 2010-12-09 13:34:00    0.0
# 19599  537870     21486     Unknown       -77 2010-12-08 17:08:00    0.0
# ...

# %%
#Dealing with Nulls/NA
#Description, Price, Customer ID has nulls

# %%
#Description nulls
df[df['Description'].isna()]
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country, Order_Status, Invoice_Date_Only, Week_Beginning]
# Index: []

# %%
df['Description'] = df['Description'].fillna('UNKNOWN')

# %%
df['Description']=df['Description'].replace('UNKNOWN','Unknown')

# %%
df[df['Description'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country, Order_Status, Invoice_Date_Only, Week_Beginning]
# Index: []

# %%
df
# Out:
#       Invoice StockCode                          Description  Quantity  \
# 39870  539708     35924        Hanging Fairy Cake Decoration         1
# 33310  539246    85114C        Red Enchanted Forest Placemat         8
# 624    536415     22910    Paper Chain Kit Vintage Christmas         5
# 11578  537254     20975  12 Pencils Small Tube Red Retrospot         4
# 30427  538864     21485     Retrospot Heart Hot Water Bottle        24
# ...       ...       ...                                  ...       ...
# 41210  539760     15036            Assorted Colours Silk Fan        12
# 19055  537827     22145      Christmas Craft Heart Stocking         30
# 5513   536864     21488    Red White Scarf  Hot Water Bottle         1
# 22171  538153     82599          Fanny'S Rest Stopmetal Sign         1
# 42301  539981    85099B              Jumbo Bag Red Retrospot        10
#
#               InvoiceDate  Price  Customer ID         Country Order_Status  \
# ...

# %%
#Price nulls 
df[df['Price']==0]
# Out:
#       Invoice StockCode                          Description  Quantity  \
# 14217  537466     21488                              Unknown       -50
# 41476  539856     22626                 Black Kitchen Scales         3
# 41449  539856    85123A   White Hanging Heart T-Light Holder         1
# 14384  537534     22550                     Holiday Fun Ludo         1
# 19625  537872     21595                              Unknown         1
# 41456  539856     37333                 Retro "Tea For One"          1
# 7191   536999     21421                              Unknown       110
# 41490  539856     22374      Airline Bag Vintage Jet Set Red         3
# 41462  539856     22684        French Blue Metal Door Sign 9         1
# 14354  537534     22501           Picnic Basket Wicker Large         2
# 1985   536547     37509                              Unknown         1
# 41484  539856     22514             Childs Garden Spade Blue         1
# ...

# %%
#Customer ID nulls
df[df['Customer ID']==0]
# Out:
#       Invoice StockCode                         Description  Quantity  \
# 39870  539708     35924       Hanging Fairy Cake Decoration         1
# 11359  537240     85177        Basket Of Flowers Sewing Kit         2
# 21278  538071     85096             Hilda Candy Spot Rabbit         1
# 40813  539743     22135          Mini Ladle Love Heart Pink         1
# 10709  537237     82582           Area Patrolled Metal Sign         1
# ...       ...       ...                                 ...       ...
# 5859   536876     22419                    Lipstick Pen Red         7
# 10331  537237     21641  Assorted Tutti Frutti Keyring Ball         1
# 22610  538177     20682    Red Retrospot Childrens Umbrella         2
# 5513   536864     21488   Red White Scarf  Hot Water Bottle         1
# 22171  538153     82599         Fanny'S Rest Stopmetal Sign         1
#
#               InvoiceDate  Price  Customer ID         Country Order_Status  \
# ...

# %%
df['Customer ID']=df['Customer ID'].fillna(0)

# %%
df[df['Customer ID']==0]
# Out:
#       Invoice StockCode                         Description  Quantity  \
# 39870  539708     35924       Hanging Fairy Cake Decoration         1
# 11359  537240     85177        Basket Of Flowers Sewing Kit         2
# 21278  538071     85096             Hilda Candy Spot Rabbit         1
# 40813  539743     22135          Mini Ladle Love Heart Pink         1
# 10709  537237     82582           Area Patrolled Metal Sign         1
# ...       ...       ...                                 ...       ...
# 5859   536876     22419                    Lipstick Pen Red         7
# 10331  537237     21641  Assorted Tutti Frutti Keyring Ball         1
# 22610  538177     20682    Red Retrospot Childrens Umbrella         2
# 5513   536864     21488   Red White Scarf  Hot Water Bottle         1
# 22171  538153     82599         Fanny'S Rest Stopmetal Sign         1
#
#               InvoiceDate  Price  Customer ID         Country Order_Status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9974 entries, 39870 to 42301
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Invoice            9974 non-null   object
#  1   StockCode          9974 non-null   object
#  2   Description        9974 non-null   object
#  3   Quantity           9974 non-null   int64
#  4   InvoiceDate        9974 non-null   datetime64[ns]
#  5   Price              9974 non-null   float64
#  6   Customer ID        9974 non-null   Int64
#  7   Country            9974 non-null   object
#  8   Order_Status       9974 non-null   object
#  9   Invoice_Date_Only  9974 non-null   object
#  10  Week_Beginning     9974 non-null   datetime64[ns]
# dtypes: Int64(1), datetime64[ns](2), float64(1), int64(1), object(6)
# memory usage: 944.8+ KB

# %%
#Set Data Types

# %%
df.dtypes
# Out:
# Invoice                      object
# StockCode                    object
# Description                  object
# Quantity                      int64
# InvoiceDate          datetime64[ns]
# Price                       float64
# Customer ID                   Int64
# Country                      object
# Order_Status                 object
# Invoice_Date_Only            object
# Week_Beginning       datetime64[ns]
# dtype: object

# %%
df['Invoice'] = pd.to_numeric(df['Invoice'], errors='coerce')

# %%
print(df['Invoice'].dtype)
# Out:
# int64

# %%
df['Invoice_Date_Only'] = pd.to_datetime(df['Invoice_Date_Only'])

# %%
print(df['Invoice_Date_Only'].dtype)
# Out:
# datetime64[ns]

# %%
df.dtypes
# Out:
# Invoice                       int64
# StockCode                    object
# Description                  object
# Quantity                      int64
# InvoiceDate          datetime64[ns]
# Price                       float64
# Customer ID                   Int64
# Country                      object
# Order_Status                 object
# Invoice_Date_Only    datetime64[ns]
# Week_Beginning       datetime64[ns]
# dtype: object

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 39870   539708     35924        Hanging Fairy Cake Decoration         1
# 33310   539246    85114C        Red Enchanted Forest Placemat         8
# 624     536415     22910    Paper Chain Kit Vintage Christmas         5
# 11578   537254     20975  12 Pencils Small Tube Red Retrospot         4
# 30427   538864     21485     Retrospot Heart Hot Water Bottle        24
# ...        ...       ...                                  ...       ...
# 41210   539760     15036            Assorted Colours Silk Fan        12
# 19055   537827     22145      Christmas Craft Heart Stocking         30
# 5513    536864     21488    Red White Scarf  Hot Water Bottle         1
# 22171   538153     82599          Fanny'S Rest Stopmetal Sign         1
# 42301   539981    85099B              Jumbo Bag Red Retrospot        10
#
#               InvoiceDate  Price  Customer ID         Country Order_Status  \
# ...
